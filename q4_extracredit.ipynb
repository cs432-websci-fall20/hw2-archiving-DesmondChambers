# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
#names of files
names = ['HTML', 'Images', 'Aud/Vid', 'PDF', 'Javascript', 'CSS', 'Fonts', 'Plain Text', 'JSON', 'DASH/HLS']

#number of files
num = [46,169,16,0,179,106,38,16,27,10]

ax.bar(names, num)
plt.show()
